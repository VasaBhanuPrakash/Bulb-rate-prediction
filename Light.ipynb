# %% [markdown]
# <a href="https://colab.research.google.com/github/VasaBhanuPrakash/Bulb-rate-prediction/blob/main/Light.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from re import I
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("lightingpermillion new.csv")

# %%
df.head()
# Out:
#                 Entity  Year  Price for Light
# 0  Price for Lightning  1301          33042.90
# 1  Price for Lightning  1302          40820.58
# 2  Price for Lightning  1303          40475.20
# 3  Price for Lightning  1304          40512.35
# 4  Price for Lightning  1305          40279.28

# %%
df.tail()
# Out:
#                   Entity  Year  Price for Light
# 701  Price for Lightning  2002              2.38
# 702  Price for Lightning  2003              2.40
# 703  Price for Lightning  2004              2.53
# 704  Price for Lightning  2005              2.67
# 705  Price for Lightning  2006              2.89

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 706 entries, 0 to 705
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Entity            706 non-null    object
#  1   Year              706 non-null    int64
#  2   Price for Light   706 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 16.7+ KB

# %%
df.dtypes
# Out:
# Entity               object
# Year                  int64
# Price for Light     float64
# dtype: object

# %%
df.describe()
# Out:
#               Year  Price for Light
# count   706.000000        706.000000
# mean   1653.500000      13677.355014
# std     203.948932      10301.644750
# min    1301.000000          2.380000
# 25%    1477.250000       3768.045000
# 50%    1653.500000      13490.095000
# 75%    1829.750000      17101.420000
# max    2006.000000      40820.580000

# %%
plt.plot(df.Year,df['Price for Light '])

# %%
x=df['Year']
x=np.reshape(x,(-1,1))

# %%
y=df['Price for Light ']
y=np.reshape(y,(-1,1))

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
l=LinearRegression()

# %%
l.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=l.predict(x_test)

# %%
print("MSE is",mean_squared_error(y_test,y_pred))
print("MAE is",mean_absolute_error(y_test,y_pred))
print("R2 score is",r2_score(y_test,y_pred))
# Out:
# MSE is 14054414.193913762
# MAE is 3081.218324054929
# R2 score is 0.8679038238504524

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test,y_pred,'*-r')
